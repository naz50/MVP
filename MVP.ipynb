# %%
import pandas as pd
import numpy as np
# %config InlineBackend.figure_format = 'png'
import matplotlib.pyplot as plt
from sklearn import datasets
import seaborn as sns
import plotly
plotly.offline.init_notebook_mode(connected=True)
import plotly.offline as py
sns.set_theme(style="whitegrid")
import plotly.express as px
import plotly.graph_objects as go
import matplotlib.colors as mcolors
from matplotlib.pyplot import figure
# %matplotlib inline 
####model libarary
from __future__ import print_function
from sklearn import metrics
#from sklearn import preprocessing
plt.style.use('ggplot')
# %matplotlib inline
np.set_printoptions(suppress=True) # Suppress scientific notation where possible
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#data=pd.read_csv('NuhaDBooo.csv',encoding="ISO-8859-1")
data=pd.read_csv('NuhaDBooo.csv')
data.head()
#df=pd.read_csv('NuhaDBNew.csv')
# Out:
#            DC   Indicator        Date        Day     City    Region  \
# 0  Cumulative  Recoveries  30/06/2021  Wednesday  Al Aqiq  Al Bahah
# 1  Cumulative  Recoveries  04/07/2021     Sunday  Al Aqiq  Al Bahah
# 2  Cumulative  Recoveries  06/07/2021    Tuesday  Al Aqiq  Al Bahah
# 3  Cumulative  Recoveries  07/07/2021  Wednesday  Al Aqiq  Al Bahah
# 4  Cumulative  Recoveries  12/07/2021     Monday  Al Aqiq  Al Bahah
#
#    CasesNumber  AvarageCases WorkHoliday        Country SpreedCovid19
# 0          730    323.274197     Workday  Saudi Arabia            LOW
# 1          730    323.274197     Workday  Saudi Arabia            LOW
# 2          730    323.274197     Workday  Saudi Arabia            LOW
# 3          730    323.274197     Workday  Saudi Arabia            LOW
# 4          730    323.274197     Workday  Saudi Arabia            LOW

# %%
data['WorkHoliday'].value_counts().plot.bar(figsize = (7, 7), title = 'Spreed Covid19', color = 'crimson')
plt.xlabel('Type of Weekday')
plt.ylabel('Frequency');
#plt.savefig('p11.png')

# %%
figure(figsize=(26, 26), dpi=100)
sns.barplot(x = 'Region',y='CasesNumber',data=data);
plt.xlabel('The Region of KSA',fontsize = 25, weight = 'bold',color='green');
plt.ylabel('The cases Number of Covid19',fontsize = 25, weight = 'bold',color='red');
#plt.savefig('p2.png')
plt.show()

# %%
figure(figsize=(26, 26), dpi=100)
sns.barplot(x="Region", y="CasesNumber", hue="Indicator", data=data, color='maroon') #maroon#indigo
#plt.savefig('p3.png')
# Out:
# <AxesSubplot:xlabel='Region', ylabel='CasesNumber'>

# %%
sns.scatterplot(data=data, x="CasesNumber", y="Region", hue="Region")
#plt.savefig('p4.png')
# Out:
# <AxesSubplot:xlabel='CasesNumber', ylabel='Region'>

# %%
sns.scatterplot(data=data, x="SpreedCovid19", y="Region", hue="Region")
#plt.savefig('p5.png')
# Out:
# <AxesSubplot:xlabel='SpreedCovid19', ylabel='Region'>

# %%
data['Region'].value_counts().plot.bar(figsize = (7, 7), title = 'Spreed Covid19', color = 'indigo')
plt.xlabel('Region')
plt.ylabel('Spreed Covid19');
#plt.savefig('p6.png')
